# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df = pd.read_parquet(r"..\artifacts\qwen3_4b_instruct_2507_21\content\artifacts\Qwen3-4B-Instruct-2507\surface\rows.parquet")

# %%
fig = px.scatter_3d(df, x="PLS1", y="PLS2", z="PLS3", color="bcpc_arc_length")
fig.update_traces(marker={"size":2})

# %%
df.columns
# Out:
# Index(['text', 'template_id', 'template_metadata', 'task', 'task_metadata',
#        'base_value', 'base_unit', 'unit_variant', 'number_format', 'value',
#        'value_text', 'unit', 'source_file', 'source_row', 'prompt',
#        'horizon_type', 'stakes_original', 'stakes', 'pls_weight_group',
#        'BCPC1', 'BCPC2', 'BCPC3', 'BCPC4', 'BCPC5', 'BCPC6', 'BCPC7',
#        'spline_parameter', 'bcpc_arc_length', 'distance_to_spline',
#        'closest_BCPC1', 'closest_BCPC2', 'closest_BCPC3', 'closest_BCPC4',
#        'closest_BCPC5', 'closest_BCPC6', 'closest_BCPC7',
#        'log10_time_horizon_months', 'pls_fit_weight', 'PLS1', 'PLS2', 'PLS3',
#        'PLS4', 'PLS5', 'PLS6', 'PLS7', 'PLS8', 'PLS9', 'PLS10', 'PLS11',
#        'PLS12', 'PLS13', 'PLS14', 'PLS15', 'PLS16', 'file', 'surface_u',
#        'surface_v', 'arc_length_parallel', 'arc_length_orthogonal',
#        'surface_projection_residual', 'slice_height_error', 'slice_index',
# ...

# %%
np.corrcoef(df["PLS1"], df["PLS4"])
# Out:
# array([[ 1.00000000e+00, -2.66121349e-15],
#        [-2.66121349e-15,  1.00000000e+00]])
